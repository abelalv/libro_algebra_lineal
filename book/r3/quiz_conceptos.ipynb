# %% [markdown]
# # Quiz: Operaciones, Subespacios y Rectas en $\mathbb{R}^2$
#
# Pon a prueba tus conocimientos sobre operaciones básicas con vectores, subespacios vectoriales y rectas paramétricas en el plano.

# %%
from jupyter_quiz import display_quiz

quiz = [
    {
        "question": "Dados los vectores $u = (2, -1)$ y $v = (0, 3)$, ¿cuál es el resultado de la operación $2u - v$?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": r"$(4, -5)$",
                "correct": True,
                "feedback": r"Correcto. $2(2, -1) - (0, 3) = (4, -2) - (0, 3) = (4, -5)$."
            },
            {
                "answer": r"$(4, 1)$",
                "correct": False,
                "feedback": "Incorrecto. Recuerda restar componente a componente: $-2 - 3 = -5$."
            },
            {
                "answer": r"$(2, 2)$",
                "correct": False,
                "feedback": "Incorrecto. Verifica la multiplicación escalar y la resta."
            }
        ]
    },
    {
        "question": r"¿Cuál de los siguientes conjuntos es un subespacio vectorial de $\mathbb{R}^2$?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": r"La recta $y = 3x$",
                "correct": True,
                "feedback": "Correcto. Es una recta que pasa por el origen, por lo tanto es cerrada bajo suma y multiplicación por escalar."
            },
            {
                "answer": r"La recta $y = 3x + 2$",
                "correct": False,
                "feedback": r"Incorrecto. Esta recta no contiene al vector cero $(0,0)$."
            },
            {
                "answer": r"El primer cuadrante ($x \ge 0, y \ge 0$)",
                "correct": False,
                "feedback": r"Incorrecto. No es cerrado bajo multiplicación por un escalar negativo (ej. $-1 \cdot (1,1) = (-1,-1)$ que sale del conjunto)."
            }
        ]
    },
    {
        "question": "Para la recta paramétrica $P = (1, 2) + t(-1, 1)$, ¿cuál de los siguientes puntos pertenece a la recta?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": r"$(0, 3)$",
                "correct": True,
                "feedback": r"Correcto. Se obtiene con $t=1$: $(1-1, 2+1) = (0,3)$."
            },
            {
                "answer": r"$(2, 3)$",
                "correct": False,
                "feedback": "Incorrecto. No existe un $t$ que satisfaga ambas coordenadas simultáneamente."
            },
            {
                "answer": r"$(1, 1)$",
                "correct": False,
                "feedback": "Incorrecto. El punto $(1,1)$ no satisface la ecuación de la recta."
            }
        ]
    },
    {
        "question": r"Si $v \in \mathbb{R}^2$ es un vector no nulo, el conjunto de todos los vectores de la forma $cv$ (con $c \in \mathbb{R}$) representa geométricamente:",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Una recta que pasa por el origen",
                "correct": True,
                "feedback": r"Correcto. Es el espacio generado por $v$."
            },
            {
                "answer": "Un punto único",
                "correct": False,
                "feedback": r"Incorrecto. Solo sería un punto si $v$ fuera el vector cero."
            },
            {
                "answer": r"Todo el plano $\mathbb{R}^2$",
                "correct": False,
                "feedback": r"Incorrecto. Un solo vector no nulo genera una recta (dimensión 1), no el plano (dimensión 2)."
            }
        ]
    }
]

display_quiz(quiz)
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:40: SyntaxWarning: invalid escape sequence '\g'
# <>:42: SyntaxWarning: invalid escape sequence '\c'
# <>:68: SyntaxWarning: invalid escape sequence '\i'
# <>:82: SyntaxWarning: invalid escape sequence '\m'
# <>:26: SyntaxWarning: invalid escape sequence '\m'
# <>:40: SyntaxWarning: invalid escape sequence '\g'
# <>:42: SyntaxWarning: invalid escape sequence '\c'
# <>:68: SyntaxWarning: invalid escape sequence '\i'
# <>:82: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_53578/3696557434.py:26: SyntaxWarning: invalid escape sequence '\m'
#   "question": "¿Cuál de los siguientes conjuntos es un subespacio vectorial de $\mathbb{R}^2$?",
# /tmp/ipykernel_53578/3696557434.py:40: SyntaxWarning: invalid escape sequence '\g'
#   "answer": "El primer cuadrante ($x \ge 0, y \ge 0$)",
# /tmp/ipykernel_53578/3696557434.py:42: SyntaxWarning: invalid escape sequence '\c'
# ...
