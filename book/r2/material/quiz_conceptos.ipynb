# %% [markdown]
# # quiz

# %%
# cell_metadata: {"tags": ["remove-input"]}

from jupyterquiz import display_quiz

# Definimos las preguntas usando el formato de bloques de código ("code")
example = [
    {
        "question": "The variable mylist is a Python list. Choose which code snippet will append the item 3 to mylist.",
        "type": "multiple_choice",
        "answers": [
            {
                "code": "mylist+=3",
                "correct": False,
                "feedback": "Incorrecto. No puedes sumar un entero a una lista directamente."
            },
            {
                "code": "mylist+=[3]",
                "correct": True,
                "feedback": "¡Correcto! Sumar una lista a otra con += concatena los elementos."
            },
            {
                "code": "mylist+={3}",
                "correct": False,
                "feedback": "Incorrecto. Esto intentaría sumar un set, lo cual daría un error de tipo."
            }
        ]
    }
]

display_quiz(example)
